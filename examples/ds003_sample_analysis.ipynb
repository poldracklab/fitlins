# %% [markdown]
# # Walk-through FitLins Analysis
#
# This document demonstrates the command line to run a FitLins analysis.
#
# We use the [OpenNeuro](https://openneuro.org) dataset [ds000003](https://openneuro.org/datasets/ds000003/),
# with [fMRIPrep](https://fmriprep.rtfd.io)-preprocessed results at
# [///labs/poldrack/ds003_fmriprep](http://datasets.datalad.org/?dir=/labs/poldrack/ds003_fmriprep).
#
# ## Preamble
#
# We will use [Datalad](https://www.datalad.org) to manage our data, which in turn depends on `git-annex`. To install `git-annex`, uncomment and run one of the following:

# %%
# Debian
# apt-get install git-annex

# %%
# Linux with Conda
# conda install -y git-annex

# %%
# OSX
# open https://git-annex.branchable.com/install/OSX/

# %% [markdown]
# Datalad and FitLins are Python tools.
# To ensure that everything installs correctly, we'll upgrade the [pip](https://pip.pypa.io/en/stable/) package manager
# and the [setuptools](https://setuptools.readthedocs.io/en/latest/) utilities.
#
# We will also install unreleased versions of Datalad and [Nistats](https://nistats.github.io/) to make things run a little more smoothly.

# %%
pip install -q --upgrade pip setuptools
pip install -q --upgrade "datalad @ git+https://github.com/yarikoptic/datalad@9512579cb50efa8b16e83760c3bab554c1ed4a25" \
                         "nistats @ git+https://github.com/nistats/nistats.git@b69e127020df05aa8ba540f9a8d799e1dad3d602"

# %% [markdown]
# ## Install data and FitLins
#
# First, install the [dataset](http://datasets.datalad.org/?dir=/labs/poldrack/ds003_fmriprep) we'll be working with.

# %%
# Set environment variable to make outputs more friendly
export DATALAD_UI_PROGRESSBAR=log

datalad install -r ///labs/poldrack/ds003_fmriprep
datalad update ds003_fmriprep
# Out:
# [INFO   ] Installing <Dataset path=/Users/markiewicz/Projects/crn/fitlins/examples/ds003_fmriprep> recursively
# action summary:
#   get (notneeded: 1)
#   install (notneeded: 2)
# [INFO   ] Fetching updates for <Dataset path=/Users/markiewicz/Projects/crn/fitlins/examples/ds003_fmriprep>
# update(ok): /Users/markiewicz/Projects/crn/fitlins/examples/ds003_fmriprep (dataset)

# %% [markdown]
# Fetch the preprocessed BOLD series and calculated confounds for the first three subjects.

# %%
datalad get ds003_fmriprep/sub-0{1,2,3}/func/*_space-MNI152NLin2009cAsym_desc-*.nii.gz \
            ds003_fmriprep/sub-0{1,2,3}/func/*_desc-confounds_*.tsv
# Out:
# action summary:
#   get (notneeded: 15)

# %% [markdown]
# Finally, install FitLins via pip. See the [Installation](https://fitlins.readthedocs.io/en/latest/installation.html)
# section of the documentation for instructions on using Docker or Singularity. For the purposes of this tutorial,
# however, we'll assume you can install to your current Python environment without issue.

# %%
pip install -q --upgrade fitlins==0.4.0

# %% [markdown]
# ## Dataset structure
#
# This dataset is organized as an fMRIPrep derivatives directory, with the original dataset included as the `sourcedata/` sub-dataset.
# The following command shows just the directories for the first three subjects. (Will probably not work with earlier versions than `tree 1.8.0`.)

# %%
tree -P "sub-0[123]*.nii.gz" -I "figures|log" --prune --noreport ds003_fmriprep | grep -v -- '->'
# Out:
# ds003_fmriprep
# ├── sourcedata
# │   ├── sub-01
# │   │   ├── anat
# │   │   └── func
# │   ├── sub-02
# │   │   ├── anat
# │   │   └── func
# │   └── sub-03
# │       ├── anat
# │       └── func
# ├── sub-01
# │   ├── anat
# │   └── func
# ├── sub-02
# │   ├── anat
# │   └── func
# └── sub-03
#     ├── anat
#     └── func

# %% [markdown]
# ### Model
#
# We will estimate the model found in `models/ds000003/models/model-001_smdl.json`:

# %%
cat models/ds000003/models/model-001_smdl.json
# Out:
# {
#   "Name": "ds003_model001",
#   "Description": "",
#   "Input": {
#     "task": "rhymejudgment"
#   },
#   "Steps": [
#     {
#       "Level": "run",
#       "Transformations": [
#         {
#           "Name": "Factor",
#           "Input": [
#             "trial_type"
#           ]
#         },
#         {
#           "Name": "Convolve",
#           "Input": ["trial_type.word", "trial_type.pseudoword"],
#           "Model": "spm"
#         }
#       ],
#       "Model": {
#         "X": [
#           "trial_type.word",
#           "trial_type.pseudoword",
#           "framewise_displacement",
#           "trans_x", "trans_y", "trans_z", "rot_x", "rot_y", "rot_z",
#           "a_comp_cor_00", "a_comp_cor_01", "a_comp_cor_02",
#           "a_comp_cor_03", "a_comp_cor_04", "a_comp_cor_05"
#         ]
#       },
#       "Contrasts": [
#         {
#           "Name": "word_gt_pseudo",
#           "ConditionList": [
#             "trial_type.word",
#             "trial_type.pseudoword"
#           ],
#           "Weights": [1, -1],
#           "Type": "t"
#         }
#       ]
#     },
#     {
#       "Level": "dataset",
#       "AutoContrasts": ["word_gt_pseudo"]
#     }
#   ]
# }

# %% [markdown]
# ## Running FitLins
#
# A BIDS App takes a BIDS dataset, a target directory and an analysis level. Use the BIDS-Raw dataset (`ds003_fmriprep/sourcedata`) as the dataset, and we'll create a new directory `output`. The `dataset` level indicates the highest level of analysis, so `run`, `session` and `subject` will be run, if found in the model.
#
# In addition, we pass `ds003_fmriprep` as with the `--derivatives` (or `-d`) flag, indicating that preprocessed data should be found there. We will also pass the model from `openfmri/ds000003/model.json`

# %%
fitlins ds003_fmriprep/sourcedata output/ dataset \
    --derivatives $PWD/ds003_fmriprep \
    --model $PWD/models/ds000003/models/model-001_smdl.json \
    --participant-label 01 02 03 \
    -w scratch \
    --n-cpus 2
# Out:
# Failed to import duecredit due to No module named 'duecredit'
# 190514-15:11:50,348 nipype.workflow INFO:
# 	 Workflow fitlins_wf settings: ['check', 'execution', 'logging', 'monitoring']
# 190514-15:11:50,446 nipype.workflow INFO:
# 	 Running in parallel.
# 190514-15:11:50,465 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190514-15:11:50,596 nipype.workflow INFO:
# 	 [Job 0] Cached (fitlins_wf.loader).
# 190514-15:11:52,457 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190514-15:11:52,519 nipype.workflow INFO:
# 	 [Job 1] Cached (fitlins_wf.select_l2_contrasts).
# 190514-15:11:52,524 nipype.workflow INFO:
# 	 [Job 2] Cached (fitlins_wf.select_l1_contrasts).
# 190514-15:11:54,455 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190514-15:11:54,507 nipype.workflow INFO:
# 	 [Job 3] Cached (fitlins_wf.select_l1_entities).
# 190514-15:11:56,457 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190514-15:11:56,593 nipype.workflow INFO:
# 	 [Job 5] Cached (fitlins_wf.getter).
# 190514-15:11:58,460 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190514-15:11:58,522 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_model_warning0" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_model_warning/mapflow/_ds_model_warning0".
# 190514-15:11:58,527 nipype.workflow INFO:
# 	 [Node] Running "_ds_model_warning0" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:11:58,538 nipype.workflow INFO:
# 	 [Node] Finished "_ds_model_warning0".
# 190514-15:11:58,538 nipype.workflow INFO:
# 	 [Job 26] Completed (_ds_model_warning0).
# 190514-15:11:58,602 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_model_warning1" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_model_warning/mapflow/_ds_model_warning1".
# 190514-15:11:58,606 nipype.workflow INFO:
# 	 [Node] Running "_ds_model_warning1" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:11:58,612 nipype.workflow INFO:
# 	 [Node] Finished "_ds_model_warning1".
# 190514-15:11:58,612 nipype.workflow INFO:
# 	 [Job 27] Completed (_ds_model_warning1).
# 190514-15:11:58,669 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_model_warning2" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_model_warning/mapflow/_ds_model_warning2".
# 190514-15:11:58,674 nipype.workflow INFO:
# 	 [Node] Running "_ds_model_warning2" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:11:58,680 nipype.workflow INFO:
# 	 [Node] Finished "_ds_model_warning2".
# 190514-15:11:58,680 nipype.workflow INFO:
# 	 [Job 28] Completed (_ds_model_warning2).
# 190514-15:12:00,462 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190514-15:12:00,549 nipype.workflow INFO:
# 	 [Node] Setting-up "fitlins_wf.ds_model_warning" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_model_warning".
# 190514-15:12:00,557 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_model_warning0" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_model_warning/mapflow/_ds_model_warning0".
# 190514-15:12:00,570 nipype.workflow INFO:
# 	 [Node] Running "_ds_model_warning0" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:00,592 nipype.workflow INFO:
# 	 [Node] Finished "_ds_model_warning0".
# 190514-15:12:00,596 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_model_warning1" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_model_warning/mapflow/_ds_model_warning1".
# 190514-15:12:00,607 nipype.workflow INFO:
# 	 [Node] Running "_ds_model_warning1" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:00,625 nipype.workflow INFO:
# 	 [Node] Finished "_ds_model_warning1".
# 190514-15:12:00,628 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_model_warning2" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_model_warning/mapflow/_ds_model_warning2".
# 190514-15:12:00,642 nipype.workflow INFO:
# 	 [Node] Running "_ds_model_warning2" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:00,667 nipype.workflow INFO:
# 	 [Node] Finished "_ds_model_warning2".
# 190514-15:12:00,674 nipype.workflow INFO:
# 	 [Node] Finished "fitlins_wf.ds_model_warning".
# 190514-15:12:00,674 nipype.workflow INFO:
# 	 [Job 4] Completed (fitlins_wf.ds_model_warning).
# 190514-15:12:00,776 nipype.workflow INFO:
# 	 [Job 29] Cached (_l1_model0).
# 190514-15:12:00,780 nipype.workflow INFO:
# 	 [Job 30] Cached (_l1_model1).
# 190514-15:12:02,462 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190514-15:12:02,522 nipype.workflow INFO:
# 	 [Job 31] Cached (_l1_model2).
# 190514-15:12:04,515 nipype.workflow INFO:
# 	 [Job 6] Cached (fitlins_wf.l1_model).
# 190514-15:12:06,465 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 6 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190514-15:12:06,558 nipype.workflow INFO:
# 	 [Job 7] Cached (fitlins_wf.l2_model).
# 190514-15:12:06,570 nipype.workflow INFO:
# 	 [Job 13] Cached (fitlins_wf.collate_l1).
# 190514-15:12:08,472 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 15 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190514-15:12:08,583 nipype.workflow INFO:
# 	 [Job 8] Cached (fitlins_wf.collate_l2).
# 190514-15:12:08,644 nipype.workflow INFO:
# 	 [Job 16] Cached (fitlins_wf.collate_l1_outputs).
# 190514-15:12:10,471 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 18 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190514-15:12:10,524 nipype.workflow INFO:
# 	 [Job 9] Cached (fitlins_wf.plot_l2_contrasts).
# 190514-15:12:10,529 nipype.workflow INFO:
# 	 [Job 11] Cached (fitlins_wf.collate_l2_outputs).
# 190514-15:12:12,526 nipype.workflow INFO:
# 	 [Node] Setting-up "fitlins_wf.ds_l2_contrast_plots" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_l2_contrast_plots".
# 190514-15:12:12,530 nipype.workflow INFO:
# 	 [Node] Running "ds_l2_contrast_plots" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:12,549 nipype.workflow INFO:
# 	 [Node] Finished "fitlins_wf.ds_l2_contrast_plots".
# 190514-15:12:12,549 nipype.workflow INFO:
# 	 [Job 10] Completed (fitlins_wf.ds_l2_contrast_plots).
# 190514-15:12:12,613 nipype.workflow INFO:
# 	 [Node] Setting-up "fitlins_wf.ds_l2_contrast_maps" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_l2_contrast_maps".
# 190514-15:12:12,617 nipype.workflow INFO:
# 	 [Node] Running "ds_l2_contrast_maps" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:12,635 nipype.workflow INFO:
# 	 [Node] Finished "fitlins_wf.ds_l2_contrast_maps".
# 190514-15:12:12,635 nipype.workflow INFO:
# 	 [Job 12] Completed (fitlins_wf.ds_l2_contrast_maps).
# 190514-15:12:12,700 nipype.workflow INFO:
# 	 [Node] Setting-up "fitlins_wf.ds_l1_contrast_maps" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_l1_contrast_maps".
# 190514-15:12:12,707 nipype.workflow INFO:
# 	 [Node] Running "ds_l1_contrast_maps" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:12,731 nipype.workflow INFO:
# 	 [Node] Finished "fitlins_wf.ds_l1_contrast_maps".
# 190514-15:12:12,731 nipype.workflow INFO:
# 	 [Job 17] Completed (fitlins_wf.ds_l1_contrast_maps).
# 190514-15:12:12,786 nipype.workflow INFO:
# 	 [Job 32] Cached (_plot_corr0).
# 190514-15:12:12,787 nipype.workflow INFO:
# 	 [Job 33] Cached (_plot_corr1).
# 190514-15:12:14,479 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 13 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190514-15:12:14,525 nipype.workflow INFO:
# 	 [Job 34] Cached (_plot_corr2).
# 190514-15:12:14,527 nipype.workflow INFO:
# 	 [Job 35] Cached (_plot_l1_contrast_matrix0).
# 190514-15:12:16,481 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 12 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190514-15:12:16,529 nipype.workflow INFO:
# 	 [Job 18] Cached (fitlins_wf.plot_corr).
# 190514-15:12:16,533 nipype.workflow INFO:
# 	 [Job 36] Cached (_plot_l1_contrast_matrix1).
# 190514-15:12:18,482 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 11 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190514-15:12:18,535 nipype.workflow INFO:
# 	 [Job 37] Cached (_plot_l1_contrast_matrix2).
# 190514-15:12:18,537 nipype.workflow INFO:
# 	 [Job 38] Cached (_deindex_tsv0).
# 190514-15:12:20,485 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 12 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190514-15:12:20,533 nipype.workflow INFO:
# 	 [Job 20] Cached (fitlins_wf.plot_l1_contrast_matrix).
# 190514-15:12:20,534 nipype.workflow INFO:
# 	 [Job 39] Cached (_deindex_tsv1).
# 190514-15:12:22,485 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 11 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190514-15:12:22,539 nipype.workflow INFO:
# 	 [Job 40] Cached (_deindex_tsv2).
# 190514-15:12:22,540 nipype.workflow INFO:
# 	 [Job 41] Cached (_plot_design0).
# 190514-15:12:24,486 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 12 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190514-15:12:24,535 nipype.workflow INFO:
# 	 [Job 22] Cached (fitlins_wf.deindex_tsv).
# 190514-15:12:24,537 nipype.workflow INFO:
# 	 [Job 42] Cached (_plot_design1).
# 190514-15:12:26,492 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 11 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190514-15:12:26,555 nipype.workflow INFO:
# 	 [Job 43] Cached (_plot_design2).
# 190514-15:12:26,558 nipype.workflow INFO:
# 	 [Job 44] Cached (_plot_l1_contrasts0).
# 190514-15:12:28,491 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 12 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190514-15:12:28,539 nipype.workflow INFO:
# 	 [Job 24] Cached (fitlins_wf.plot_design).
# 190514-15:12:28,542 nipype.workflow INFO:
# 	 [Job 45] Cached (_plot_l1_contrasts1).
# 190514-15:12:30,492 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 11 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190514-15:12:30,549 nipype.workflow INFO:
# 	 [Job 46] Cached (_plot_l1_contrasts2).
# 190514-15:12:30,551 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_corr0" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_corr/mapflow/_ds_corr0".
# 190514-15:12:30,556 nipype.workflow INFO:
# 	 [Node] Running "_ds_corr0" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:30,573 nipype.workflow INFO:
# 	 [Node] Finished "_ds_corr0".
# 190514-15:12:30,573 nipype.workflow INFO:
# 	 [Job 47] Completed (_ds_corr0).
# 190514-15:12:30,637 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_corr1" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_corr/mapflow/_ds_corr1".
# 190514-15:12:30,641 nipype.workflow INFO:
# 	 [Node] Running "_ds_corr1" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:30,668 nipype.workflow INFO:
# 	 [Node] Finished "_ds_corr1".
# 190514-15:12:30,669 nipype.workflow INFO:
# 	 [Job 48] Completed (_ds_corr1).
# 190514-15:12:30,727 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_corr2" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_corr/mapflow/_ds_corr2".
# 190514-15:12:30,732 nipype.workflow INFO:
# 	 [Node] Running "_ds_corr2" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:30,746 nipype.workflow INFO:
# 	 [Node] Finished "_ds_corr2".
# 190514-15:12:30,746 nipype.workflow INFO:
# 	 [Job 49] Completed (_ds_corr2).
# 190514-15:12:30,809 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_l1_contrasts0" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_l1_contrasts/mapflow/_ds_l1_contrasts0".
# 190514-15:12:30,814 nipype.workflow INFO:
# 	 [Node] Running "_ds_l1_contrasts0" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:30,828 nipype.workflow INFO:
# 	 [Node] Finished "_ds_l1_contrasts0".
# 190514-15:12:30,828 nipype.workflow INFO:
# 	 [Job 50] Completed (_ds_l1_contrasts0).
# 190514-15:12:30,889 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_l1_contrasts1" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_l1_contrasts/mapflow/_ds_l1_contrasts1".
# 190514-15:12:30,895 nipype.workflow INFO:
# 	 [Node] Running "_ds_l1_contrasts1" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:30,911 nipype.workflow INFO:
# 	 [Node] Finished "_ds_l1_contrasts1".
# 190514-15:12:30,912 nipype.workflow INFO:
# 	 [Job 51] Completed (_ds_l1_contrasts1).
# 190514-15:12:30,984 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_l1_contrasts2" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_l1_contrasts/mapflow/_ds_l1_contrasts2".
# 190514-15:12:30,988 nipype.workflow INFO:
# 	 [Node] Running "_ds_l1_contrasts2" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:31,4 nipype.workflow INFO:
# 	 [Node] Finished "_ds_l1_contrasts2".
# 190514-15:12:31,4 nipype.workflow INFO:
# 	 [Job 52] Completed (_ds_l1_contrasts2).
# 190514-15:12:31,66 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_design_matrix0" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_design_matrix/mapflow/_ds_design_matrix0".
# 190514-15:12:31,71 nipype.workflow INFO:
# 	 [Node] Running "_ds_design_matrix0" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:31,86 nipype.workflow INFO:
# 	 [Node] Finished "_ds_design_matrix0".
# 190514-15:12:31,86 nipype.workflow INFO:
# 	 [Job 53] Completed (_ds_design_matrix0).
# 190514-15:12:31,147 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_design_matrix1" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_design_matrix/mapflow/_ds_design_matrix1".
# 190514-15:12:31,153 nipype.workflow INFO:
# 	 [Node] Running "_ds_design_matrix1" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:31,168 nipype.workflow INFO:
# 	 [Node] Finished "_ds_design_matrix1".
# 190514-15:12:31,168 nipype.workflow INFO:
# 	 [Job 54] Completed (_ds_design_matrix1).
# 190514-15:12:31,243 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_design_matrix2" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_design_matrix/mapflow/_ds_design_matrix2".
# 190514-15:12:31,250 nipype.workflow INFO:
# 	 [Node] Running "_ds_design_matrix2" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:31,265 nipype.workflow INFO:
# 	 [Node] Finished "_ds_design_matrix2".
# 190514-15:12:31,265 nipype.workflow INFO:
# 	 [Job 55] Completed (_ds_design_matrix2).
# 190514-15:12:32,494 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 7 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190514-15:12:32,542 nipype.workflow INFO:
# 	 [Job 14] Cached (fitlins_wf.plot_l1_contrasts).
# 190514-15:12:32,545 nipype.workflow INFO:
# 	 [Node] Setting-up "fitlins_wf.ds_corr" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_corr".
# 190514-15:12:32,550 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_corr0" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_corr/mapflow/_ds_corr0".
# 190514-15:12:32,555 nipype.workflow INFO:
# 	 [Node] Running "_ds_corr0" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:32,568 nipype.workflow INFO:
# 	 [Node] Finished "_ds_corr0".
# 190514-15:12:32,569 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_corr1" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_corr/mapflow/_ds_corr1".
# 190514-15:12:32,574 nipype.workflow INFO:
# 	 [Node] Running "_ds_corr1" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:32,587 nipype.workflow INFO:
# 	 [Node] Finished "_ds_corr1".
# 190514-15:12:32,589 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_corr2" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_corr/mapflow/_ds_corr2".
# 190514-15:12:32,593 nipype.workflow INFO:
# 	 [Node] Running "_ds_corr2" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:32,607 nipype.workflow INFO:
# 	 [Node] Finished "_ds_corr2".
# 190514-15:12:32,611 nipype.workflow INFO:
# 	 [Node] Finished "fitlins_wf.ds_corr".
# 190514-15:12:32,612 nipype.workflow INFO:
# 	 [Job 19] Completed (fitlins_wf.ds_corr).
# 190514-15:12:32,673 nipype.workflow INFO:
# 	 [Node] Setting-up "fitlins_wf.ds_l1_contrasts" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_l1_contrasts".
# 190514-15:12:32,678 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_l1_contrasts0" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_l1_contrasts/mapflow/_ds_l1_contrasts0".
# 190514-15:12:32,682 nipype.workflow INFO:
# 	 [Node] Running "_ds_l1_contrasts0" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:32,695 nipype.workflow INFO:
# 	 [Node] Finished "_ds_l1_contrasts0".
# 190514-15:12:32,696 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_l1_contrasts1" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_l1_contrasts/mapflow/_ds_l1_contrasts1".
# 190514-15:12:32,701 nipype.workflow INFO:
# 	 [Node] Running "_ds_l1_contrasts1" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:32,713 nipype.workflow INFO:
# 	 [Node] Finished "_ds_l1_contrasts1".
# 190514-15:12:32,715 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_l1_contrasts2" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_l1_contrasts/mapflow/_ds_l1_contrasts2".
# 190514-15:12:32,719 nipype.workflow INFO:
# 	 [Node] Running "_ds_l1_contrasts2" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:32,733 nipype.workflow INFO:
# 	 [Node] Finished "_ds_l1_contrasts2".
# 190514-15:12:32,736 nipype.workflow INFO:
# 	 [Node] Finished "fitlins_wf.ds_l1_contrasts".
# 190514-15:12:32,736 nipype.workflow INFO:
# 	 [Job 21] Completed (fitlins_wf.ds_l1_contrasts).
# 190514-15:12:32,802 nipype.workflow INFO:
# 	 [Node] Setting-up "fitlins_wf.ds_design_matrix" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_design_matrix".
# 190514-15:12:32,808 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_design_matrix0" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_design_matrix/mapflow/_ds_design_matrix0".
# 190514-15:12:32,813 nipype.workflow INFO:
# 	 [Node] Running "_ds_design_matrix0" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:32,826 nipype.workflow INFO:
# 	 [Node] Finished "_ds_design_matrix0".
# 190514-15:12:32,828 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_design_matrix1" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_design_matrix/mapflow/_ds_design_matrix1".
# 190514-15:12:32,834 nipype.workflow INFO:
# 	 [Node] Running "_ds_design_matrix1" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:32,848 nipype.workflow INFO:
# 	 [Node] Finished "_ds_design_matrix1".
# 190514-15:12:32,850 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_design_matrix2" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_design_matrix/mapflow/_ds_design_matrix2".
# 190514-15:12:32,854 nipype.workflow INFO:
# 	 [Node] Running "_ds_design_matrix2" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:32,870 nipype.workflow INFO:
# 	 [Node] Finished "_ds_design_matrix2".
# 190514-15:12:32,874 nipype.workflow INFO:
# 	 [Node] Finished "fitlins_wf.ds_design_matrix".
# 190514-15:12:32,874 nipype.workflow INFO:
# 	 [Job 23] Completed (fitlins_wf.ds_design_matrix).
# 190514-15:12:32,939 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_design0" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_design/mapflow/_ds_design0".
# 190514-15:12:32,952 nipype.workflow INFO:
# 	 [Node] Running "_ds_design0" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:32,967 nipype.workflow INFO:
# 	 [Node] Finished "_ds_design0".
# 190514-15:12:32,968 nipype.workflow INFO:
# 	 [Job 56] Completed (_ds_design0).
# 190514-15:12:33,37 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_design1" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_design/mapflow/_ds_design1".
# 190514-15:12:33,43 nipype.workflow INFO:
# 	 [Node] Running "_ds_design1" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:33,59 nipype.workflow INFO:
# 	 [Node] Finished "_ds_design1".
# 190514-15:12:33,59 nipype.workflow INFO:
# 	 [Job 57] Completed (_ds_design1).
# 190514-15:12:33,122 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_design2" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_design/mapflow/_ds_design2".
# 190514-15:12:33,127 nipype.workflow INFO:
# 	 [Node] Running "_ds_design2" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:33,140 nipype.workflow INFO:
# 	 [Node] Finished "_ds_design2".
# 190514-15:12:33,140 nipype.workflow INFO:
# 	 [Job 58] Completed (_ds_design2).
# 190514-15:12:34,493 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 2/2.
# 190514-15:12:34,592 nipype.workflow INFO:
# 	 [Node] Setting-up "fitlins_wf.ds_l1_contrast_plots" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_l1_contrast_plots".
# 190514-15:12:34,605 nipype.workflow INFO:
# 	 [Node] Running "ds_l1_contrast_plots" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:34,635 nipype.workflow INFO:
# 	 [Node] Finished "fitlins_wf.ds_l1_contrast_plots".
# 190514-15:12:34,636 nipype.workflow INFO:
# 	 [Job 15] Completed (fitlins_wf.ds_l1_contrast_plots).
# 190514-15:12:34,811 nipype.workflow INFO:
# 	 [Node] Setting-up "fitlins_wf.ds_design" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_design".
# 190514-15:12:34,828 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_design0" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_design/mapflow/_ds_design0".
# 190514-15:12:34,844 nipype.workflow INFO:
# 	 [Node] Running "_ds_design0" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:34,874 nipype.workflow INFO:
# 	 [Node] Finished "_ds_design0".
# 190514-15:12:34,876 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_design1" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_design/mapflow/_ds_design1".
# 190514-15:12:34,892 nipype.workflow INFO:
# 	 [Node] Running "_ds_design1" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:34,923 nipype.workflow INFO:
# 	 [Node] Finished "_ds_design1".
# 190514-15:12:34,926 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_design2" in "/Users/markiewicz/Projects/crn/fitlins/examples/scratch/fitlins_wf/ds_design/mapflow/_ds_design2".
# 190514-15:12:34,938 nipype.workflow INFO:
# 	 [Node] Running "_ds_design2" ("fitlins.interfaces.bids.BIDSDataSink")
# 190514-15:12:34,970 nipype.workflow INFO:
# 	 [Node] Finished "_ds_design2".
# 190514-15:12:34,979 nipype.workflow INFO:
# 	 [Node] Finished "fitlins_wf.ds_design".
# 190514-15:12:34,980 nipype.workflow INFO:
# 	 [Job 25] Completed (fitlins_wf.ds_design).
